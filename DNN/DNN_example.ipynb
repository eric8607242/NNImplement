# %% [markdown]
# # DNN
# ### by EricHuang

# %%
from DNN import DNN
dnn = DNN([20, 20], 0.0, 2e-3, 1e-2)

# %% [markdown]
# ## Load data

# %%
dnn.load_data()
dnn.visualize_data()

# %% [markdown]
# ## The weight before training

# %%
dnn.visualize_weight()

# %% [markdown]
# ## Tuning the hyperparameter

# %%
dnn.tuning_hyperparameter([1e-6, 1e-2], [1e-3, 1e-2])
# Out:
# ----- learning rate 0.000001 ----- std 0.001000 -----
# ----- Validation data Accuracy ----- 0.083000
# ----- learning rate 0.000001 ----- std 0.003250 -----
# ----- Validation data Accuracy ----- 0.113000
# ----- learning rate 0.000001 ----- std 0.005500 -----
# ----- Validation data Accuracy ----- 0.100000
# ----- learning rate 0.000001 ----- std 0.007750 -----
# ----- Validation data Accuracy ----- 0.097000
# ----- learning rate 0.000001 ----- std 0.010000 -----
# ----- Validation data Accuracy ----- 0.114000
# ----- learning rate 0.002501 ----- std 0.001000 -----
# ----- Validation data Accuracy ----- 0.111000
# ----- learning rate 0.002501 ----- std 0.003250 -----
# ----- Validation data Accuracy ----- 0.206000
# ----- learning rate 0.002501 ----- std 0.005500 -----
# ----- Validation data Accuracy ----- 0.279000
# ----- learning rate 0.002501 ----- std 0.007750 -----
# ----- Validation data Accuracy ----- 0.311000
# ----- learning rate 0.002501 ----- std 0.010000 -----
# ...

# %%
dnn.train()
# Out:
# Epoch 0 ----- Iteration 0 ----- Loss 2.305976-----
# ----- Training data Accuracy ----- 0.087122
# Epoch 0 ----- Iteration 200 ----- Loss 1.753742-----
# ----- Training data Accuracy ----- 0.349857
# Epoch 1 ----- Iteration 0 ----- Loss 1.791366-----
# ----- Training data Accuracy ----- 0.365306
# Epoch 1 ----- Iteration 200 ----- Loss 1.650387-----
# ----- Training data Accuracy ----- 0.403510
# Epoch 2 ----- Iteration 0 ----- Loss 1.702676-----
# ----- Training data Accuracy ----- 0.411429
# Epoch 2 ----- Iteration 200 ----- Loss 1.581360-----
# ----- Training data Accuracy ----- 0.427102
# Epoch 3 ----- Iteration 0 ----- Loss 1.623159-----
# ----- Training data Accuracy ----- 0.436959
# Epoch 3 ----- Iteration 200 ----- Loss 1.545716-----
# ----- Training data Accuracy ----- 0.443388
# Epoch 4 ----- Iteration 0 ----- Loss 1.593719-----
# ----- Training data Accuracy ----- 0.450061
# Epoch 4 ----- Iteration 200 ----- Loss 1.519282-----
# ----- Training data Accuracy ----- 0.455327
# ...

# %% [markdown]
# ## The weight after training

# %%
dnn.visualize_weight()
