# %% [markdown]
# # FC
# ### by EricHuang

# %%
from FC import FC
fc = FC([20, 20], 0.0, 2e-3, 1e-2)

# %% [markdown]
# ## Load data

# %%
fc.load_data()
fc.visualize_data()

# %% [markdown]
# ## The weight before training

# %%
fc.visualize_weight()

# %% [markdown]
# ## Tuning the hyperparameter

# %%
fc.tuning_hyperparameter([1e-6, 1e-2], [1e-3, 1e-2])
# Out:
# ----- learning rate 0.000001 ----- std 0.001000 -----
# ----- Validation data Accuracy ----- 0.094000
# ----- learning rate 0.000001 ----- std 0.003250 -----
# ----- Validation data Accuracy ----- 0.103000
# ----- learning rate 0.000001 ----- std 0.005500 -----
# ----- Validation data Accuracy ----- 0.103000
# ----- learning rate 0.000001 ----- std 0.007750 -----
# ----- Validation data Accuracy ----- 0.111000
# ----- learning rate 0.000001 ----- std 0.010000 -----
# ----- Validation data Accuracy ----- 0.084000
# ----- learning rate 0.002501 ----- std 0.001000 -----
# ----- Validation data Accuracy ----- 0.147000
# ----- learning rate 0.002501 ----- std 0.003250 -----
# ----- Validation data Accuracy ----- 0.210000
# ----- learning rate 0.002501 ----- std 0.005500 -----
# ----- Validation data Accuracy ----- 0.275000
# ----- learning rate 0.002501 ----- std 0.007750 -----
# ----- Validation data Accuracy ----- 0.335000
# ----- learning rate 0.002501 ----- std 0.010000 -----
# ...

# %%
fc.train()
# Out:
# Epoch 0 ----- Iteration 0 ----- Loss 2.307602-----
# ----- Training data Accuracy ----- 0.103592
# Epoch 0 ----- Iteration 200 ----- Loss 1.728517-----
# ----- Training data Accuracy ----- 0.356061
# Epoch 1 ----- Iteration 0 ----- Loss 1.809958-----
# ----- Training data Accuracy ----- 0.377163
# Epoch 1 ----- Iteration 200 ----- Loss 1.620322-----
# ----- Training data Accuracy ----- 0.408388
# Epoch 2 ----- Iteration 0 ----- Loss 1.699105-----
# ----- Training data Accuracy ----- 0.425980
# Epoch 2 ----- Iteration 200 ----- Loss 1.541670-----
# ----- Training data Accuracy ----- 0.433102
# Epoch 3 ----- Iteration 0 ----- Loss 1.659137-----
# ----- Training data Accuracy ----- 0.446265
# Epoch 3 ----- Iteration 200 ----- Loss 1.513626-----
# ----- Training data Accuracy ----- 0.446673
# Epoch 4 ----- Iteration 0 ----- Loss 1.628846-----
# ----- Training data Accuracy ----- 0.455143
# Epoch 4 ----- Iteration 200 ----- Loss 1.488651-----
# ----- Training data Accuracy ----- 0.456102
# ...

# %% [markdown]
# ## The weight after training

# %%
fc.visualize_weight()
